# %%
import pandas as pd

# %%
data = pd.read_csv("city_data.csv")
data
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# 0                  Ambon City  -3.6954  128.1814     78.94        83
# 1    Arrondissement de Troyes  48.3333    4.0833     57.25        88
# 2                     Ushuaia -54.8000  -68.3000     44.26        57
# 3                 George Town   5.4112  100.3354     80.53        83
# 4                      Faanui -16.4833 -151.7500     79.52        76
# ..                        ...      ...       ...       ...       ...
# 556                   Markova  48.6758   24.4138     58.05        81
# 557                     Pasni  25.2631   63.4710     81.37        83
# 558            Sena Madureira  -9.0656  -68.6569     79.81        73
# 559                 Kovylkino  54.0388   43.9139     49.26        79
# 560                 Lewistown  40.5992  -77.5714     70.25       100
#
#      Cloudiness  Wind Speed Country        Date
# 0            20        1.14      ID  1654640184
# ...

# %%
html_string = data.to_html()

# %%
html_string.replace(':', '')
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align right;">\n      <th></th>\n      <th>City</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Max Temp</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n      <th>Wind Speed</th>\n      <th>Country</th>\n      <th>Date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Ambon City</td>\n      <td>-3.6954</td>\n      <td>128.1814</td>\n      <td>78.94</td>\n      <td>83</td>\n      <td>20</td>\n      <td>1.14</td>\n      <td>ID</td>\n      <td>1654640184</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Arrondissement de Troyes</td>\n      <td>48.3333</td>\n      <td>4.0833</td>\n      <td>57.25</td>\n      <td>88</td>\n      <td>0</td>\n      <td>5.75</td>\n      <td>FR</td>\n      <td>1654640185</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Ushuaia</td>\n      <td>-54.8000</td>\n      <td>-68.3000</td>\n      <td>44.26</td>\n      <td>57</td>\n      <td>20<
# ...

# %%
print(html_string)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Humidity</th>
#       <th>Cloudiness</th>
#       <th>Wind Speed</th>
#       <th>Country</th>
#       <th>Date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Ambon City</td>
#       <td>-3.6954</td>
#       <td>128.1814</td>
#       <td>78.94</td>
#       <td>83</td>
#       <td>20</td>
#       <td>1.14</td>
#       <td>ID</td>
#       <td>1654640184</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Arrondissement de Troyes</td>
#       <td>48.3333</td>
#       <td>4.0833</td>
#       <td>57.25</td>
#       <td>88</td>
#       <td>0</td>
#       <td>5.75</td>
#       <td>FR</td>
#       <td>1654640185</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Ushuaia</td>
#       <td>-54.8000</td>
#       <td>-68.3000</td>
# ...
